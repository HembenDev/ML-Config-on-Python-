# %%
import seaborn as sns
print(sns.__spec__)
# Out:
# ModuleSpec(name='seaborn', loader=<_frozen_importlib_external.SourceFileLoader object at 0x0000025CFD3D7830>, origin='c:\\Users\\Codex_Jay\\Desktop\\Python\\venv\\Lib\\site-packages\\seaborn\\__init__.py', submodule_search_locations=['c:\\Users\\Codex_Jay\\Desktop\\Python\\venv\\Lib\\site-packages\\seaborn'])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = [1,3,2,4,5]
sns.lineplot(data=data)
plt.show()

# %%
numbers = [1,2,3,4,4,5]
total = sum(numbers)
print(f'Total Numbers: {total}')
# Out:
# Total Numbers: 19
